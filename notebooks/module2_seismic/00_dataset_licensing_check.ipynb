# %% [markdown]
# # 00 — Dataset Licensing Check
#
# Hard gate per the Module 2 development doc: confirm commercial-use licensing
# on any dataset **before** it's used to train a model that ships in a paid product.
#
# Verified directly against source (not a secondary summary) on the date this
# notebook was committed:
#
# | Dataset | License | Source checked | Commercial use | Attribution required |
# |---|---|---|---|---|
# | STEAD | CC BY 4.0 | https://github.com/smousavi05/STEAD/blob/master/LICENSE | Yes | Yes |
# | INSTANCE | CC BY 4.0 | https://github.com/INGV/instance | Yes | Yes |
#
# Both licenses grant a "worldwide, royalty-free, non-sublicensable, non-exclusive,
# irrevocable license," with attribution (creator identification + copyright notice
# + license reference + indication of modifications) as the only condition.
#
# **Re-check before shipping**: dataset terms can change. This table should be
# re-verified against the live LICENSE files, not just this notebook, before any
# model trained on this data ships in a paid product — this is a point-in-time
# check, not a permanent clearance.

# %%
LICENSE_VERDICT = {
    "STEAD": {"license": "CC BY 4.0", "commercial_use": True, "attribution_required": True,
               "source_checked": "https://github.com/smousavi05/STEAD/blob/master/LICENSE"},
    "INSTANCE": {"license": "CC BY 4.0", "commercial_use": True, "attribution_required": True,
                  "source_checked": "https://github.com/INGV/instance"},
}
for name, verdict in LICENSE_VERDICT.items():
    print(f"{name}: {verdict['license']} — commercial use OK, attribution required")
